# %%
import xarray as xr
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import sys

# %% [markdown]
# ### notes
#
# - copy time axes, because there are differences `TSpet['time'] = TSpr.time`
# - first calculate reference climate

# %% [markdown]
# ### Here we calculate integrated timeseries for the Rhine region

# %%
var='pet'
freq='Amon'
timeslice='PD'
i='01'
j='0'
diri='/perm/nklm/Px_drought/testing/LENTIS/'

ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 120, bnds: 2, lon: 512, lat: 256)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-01-16T12:00:00 ... 2009-12-16T12:00:00
#   * lon        (lon) float64 -180.0 -179.3 -178.6 -177.9 ... 177.9 178.6 179.3
#   * lat        (lat) float64 -89.46 -88.77 -88.07 -87.37 ... 88.07 88.77 89.46
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lon_bnds   (lon, bnds) float64 ...
#     lat_bnds   (lat, bnds) float64 ...
#     pr         (time, lat, lon) float32 ...
# Attributes: (12/52)
#     CDI:                                Climate Data Interface version 2.1.1 ...
#     source:                             EC-Earth3 (2019): \naerosol: none\nat...
#     institution:                        The Royal Netherlands Meteorological ...
#     Conventions:                        CF-1.7 CMIP-6.2
#     activity_id:                        CMIP
#     branch_method:                      standard
# ...

# %%
TSpr, box_seasons = calc_boxstat(ds, 'pr', area='rhine')

# %%
TSpet, box_seasons = calc_boxstat(ds, 'pet_pm_asce', area='rhine')

# %%
ds.pet_pm_asce
# Out:
# <xarray.DataArray 'pet_pm_asce' (time: 120, lat: 256, lon: 512)>
# [15728640 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-16T12:00:00 ... 2009-12-16T12:00:00
#   * lon      (lon) float64 -180.0 -179.3 -178.6 -177.9 ... 177.9 178.6 179.3
#   * lat      (lat) float64 -89.46 -88.77 -88.07 -87.37 ... 88.07 88.77 89.46
# Attributes:
#     standard_name:     pet_ASCE_PM
#     long_name:         Potential evapotranspiration with ASCE Penman-Monteith
#     units:             mm day-1
#     CDI_grid_type:     gaussian
#     CDI_grid_num_LPE:  128
#     cell_methods:      time: mean
#     comment:           The surface potential evapotranspiration with the ASCE...

# %%
TSpr.shape
# Out:
# (120,)

# %%
import rhine_myd_func as func

# %%
# import os
# os.environ['R_HOME']  = '/usr/local/apps/R/4.2.2/lib64/R/' # change as needed
# os.environ["PATH"] = r"/usr/local/apps/node/18.13.0/bin:/usr/local/apps/python3/3.10.10-01/bin:/etc/ecmwf/ssd/ssd1/tmpdirs/nklm.31061218/bin:/perm/nklm/mambaforge/bin:/perm/nklm/mambaforge/condabin:/usr/local/apps/ncview/2.1.7/bin:/usr/local/apps/cdo/2.1.1/bin:/usr/local/apps/git/2.39.1/bin:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin:/perm/ms/nl/nklm/Downloads/julia-1.0.5/bin:/home/nklm/.local/bin:/home/nklm/bin" + ":" + os.environ["R_HOME"] 


import rpy2

# %%
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri
# import functions (and packages) from R
r_time_series = robjects.r('ts')

# %%
import rpy2.rinterface
#rpy2.rinterface.set_initoptions((b'rpy2', b'--no-save', b'--no-restore', b'--quiet'))
from rpy2.robjects.packages import importr
base = importr('base')
print(base._libPaths())
# Out:
# [1] "/etc/ecmwf/nfs/dh2_perm_b/nklm/mambaforge/lib/R/library"

# %%
# install the SPEI package from R

# %%
# import rpy2's package module
import rpy2.robjects.packages as rpackages

# import R's utility package
utils = rpackages.importr('utils')

# select a mirror for R packages
# utils.chooseCRANmirror(ind=1) # select the first mirror in the list
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x15276fbdbb00> [RTYPES.NILSXP]

# %%
# # R package names
# packnames = ('SPEI')

# # R vector of strings
# from rpy2.robjects.vectors import StrVector

# # Selectively install what needs to be install.
# # We are fancy, just because we can.
# names_to_install = [x for x in packnames if not rpackages.isinstalled(x)]
# if len(names_to_install) > 0:
#     utils.install_packages(StrVector(names_to_install))

# %%
# 
# utils.chooseCRANmirror(ind=2) # select the first mirror in the list
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x15276fbdbb00> [RTYPES.NILSXP]

# %%
utils.install_packages('SPEI', repos="https://cran.stat.unipd.it/")
# Out:
# R[write to console]: also installing the dependencies ‘colorspace’, ‘utf8’, ‘RcppArmadillo’, ‘elliptic’, ‘contfrac’, ‘deSolve’, ‘nlme’, ‘Matrix’, ‘farver’, ‘labeling’, ‘munsell’, ‘R6’, ‘RColorBrewer’, ‘viridisLite’, ‘fansi’, ‘magrittr’, ‘pillar’, ‘pkgconfig’, ‘cpp11’, ‘goftest’, ‘Lmoments’, ‘MASS’, ‘Rcpp’, ‘hypergeo’, ‘plyr’, ‘cli’, ‘glue’, ‘gtable’, ‘isoband’, ‘lifecycle’, ‘mgcv’, ‘rlang’, ‘scales’, ‘tibble’, ‘vctrs’, ‘withr’, ‘backports’, ‘lattice’, ‘generics’, ‘timechange’, ‘lmomco’, ‘lmom’, ‘TLMoments’, ‘reshape’, ‘ggplot2’, ‘checkmate’, ‘zoo’, ‘lubridate’
#
#
# R[write to console]: trying URL 'https://cran.stat.unipd.it/src/contrib/colorspace_2.1-0.tar.gz'
#
# R[write to console]: Content type 'application/octet-stream'
# R[write to console]:  length 2116339 bytes (2.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# packnames = ('SPEI')
# from rpy2.robjects.vectors import StrVector
# utils.install_packages(StrVector(packnames))
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x15276fbdbb00> [RTYPES.NILSXP]

# %%
SPEI_package = importr('SPEI')
r_spei_function = robjects.r['spei']

# %%
spei_scale = [1]

# %%
da_spei = np.full(TSpr.shape,np.nan)

# %%
r_ts_wb = r_time_series(robjects.FloatVector((TSpr*60*60*24) - TSpet), start = robjects.IntVector([ds.time.dt.year[0].values, ds.time.dt.month[0].values]), frequency = 12)

# %%
r_wb_values=np.array(r_ts_wb)

# %%
TSpet['time'] = TSpr.time

# %%
np.shape(r_wb_values)
# Out:
# (120,)

# %%
import pandas as pd

# %%
TSpet['time'] = TSpr.time

# %%
#plt.plot(r_wb_values, label='calc_wb')
wb=((TSpr*60*60*24) - TSpet)
plt.plot(wb, label='wb: pr-pet')
plt.legend()

# %%
r_spei = r_spei_function(r_ts_wb, scale=spei_scale[0], na_rm=True, ref_start=robjects.IntVector([func.spei_ref[0], 1]), ref_end=robjects.IntVector([func.spei_ref[1], 12]), distibution='log-Logistic')
# Out:
# [1] "Calculating the Standardized Precipitation Evapotranspiration Index (SPEI) at a time scale of 1. Using kernel type 'rectangular', with 0 shift. Fitting the data to a log-Logistic distribution. Using the ub-pwm parameter fitting method. Missing values (`NA`) will not be considered in the calculation. Using a user-specified reference period. Input type is tsvector. Time series spanning Jan 2000 to Dec 2009, with frequency = 12."

# %%
r_spei_values = pandas2ri.ri2py_vector(r_spei.rx2('fitted'))

# %%
idx
# Out:
# array([ 1, 19, 48, 70, 80])

# %%
np.isclose(r_spei_values, -1, atol=0.2)
# Out:
# array([False,  True,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False,  True, False, False, False, False, False, False, False,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False,  True, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True,  True])

# %%
fig,ax = plt.subplots(1, 1,figsize=(14,4))

plt.axhline(y=-1, color='r', linestyle='-')
plt.axhline(y=0, color='k', linestyle='-', linewidth=0.5)
plt.plot(r_spei_values, label='SPEI1')

# idx = np.argwhere(np.isclose(r_spei_values, -1, atol=0.1)).reshape(-1)

# for i in range(0,np.shape(idx)[0]):
#     plt.axvline(x=idx[i]) #x3[idx], y2_new[idx], 'ro')

xaxis = range(0,np.shape(r_spei_values)[0])
plt.fill_between(xaxis,-1,r_spei_values,where =  (r_spei_values <= -1), color='r',alpha=0.3,linewidth=0,zorder=5)


plt.legend()
plt.title('SPEI1 in the Rhine basin based on monthly values')
# Out:
# Text(0.5, 1.0, 'SPEI1 in the Rhine basin based on monthly values')

# %%
plt.plot((TSpr*60*60*24*30), label='precip')
plt.plot(TSpet*30, label='pet')
plt.plot(wb*30, label='wb')
plt.legend()
plt.title('Waterbalance in mm/day in the Rhine basin')
# Out:
# Text(0.5, 1.0, 'Waterbalance in mm/day in the Rhine basin')

# %% [markdown]
# ### make a reference for SPEI

# %%
ncfile_template = xr.open_dataset('/perm/nklm/Px_drought/testing/LENTIS/PD/Amon/pr/pr_h010.nc')
da_pr_template = ncfile_template.data_vars['pr']

path = '/perm/nklm/Px_drought/testing/LENTIS/PD/Amon/pr/' #<-- voor PD

#For n ensembles
n = 1

new_reference = xr.DataArray(np.zeros((n*12,256,512)),coords=dict(time=np.arange(n*12),lon=da_pr_template.coords['lon'],lat=da_pr_template.coords['lat']),dims=["time","lat","lon"])

for i in range(n):
    if i%10 == 0:
        print(i)
    
    name = "pr_h0" + str(i+10) + ".nc"
    if (i >= 90):
        name = "pr_h" + str(i+10) + ".nc"
    path_comp = path + name
    ncfile1 = xr.open_dataset(path_comp)
    temp1 = ncfile1.data_vars['pr']
    enkel_2005 = xr.DataArray(temp1.sel(time=slice('2005-01-01', '2006-01-01')),coords=dict(time=np.arange(i*12,i*12+12),lon=da_pr_template.coords['lon'],lat=da_pr_template.coords['lat']),dims=["time","lat","lon"])
    ncfile1.close()
    new_reference[i*12:(i*12+12)] = enkel_2005[:]
    
#da_pr_template.sel(time=slice('2005-01-01', '2006-01-01')) #<-- dit werkt, levert 12 data op
new_reference[12:24]
new_reference.name = 'pr'

pr_ref = new_reference

#om op te slaan (un-hashtaggen)
#new_reference.to_netcdf('/usr/people/slomp/Documents/Stage/prec_ref/ref_2005_n160.nc')
# Out:
# 0

# %%
ncfile_template = xr.open_dataset('/perm/nklm/Px_drought/testing/LENTIS/PD/Amon/pet/pet_h010.nc')
da_pet_template = ncfile_template.data_vars['pet_pm_asce']

path = '/perm/nklm/Px_drought/testing/LENTIS/PD/Amon/pet/' #<-- voor PD

#For n ensembles
n = 1

new_reference = xr.DataArray(np.zeros((n*12,256,512)),coords=dict(time=np.arange(n*12),lon=da_pet_template.coords['lon'],lat=da_pet_template.coords['lat']),dims=["time","lat","lon"])

for i in range(n):
    if i%10 == 0:
        print(i)
    
    name = "pet_h0" + str(i+10) + ".nc"
    if (i >= 90):
        name = "pet_h" + str(i+10) + ".nc"
    path_comp = path + name
    ncfile1 = xr.open_dataset(path_comp)
    temp1 = ncfile1.data_vars['pet_pm_asce']
    enkel_2005 = xr.DataArray(temp1.sel(time=slice('2005-01-01', '2006-01-01')),coords=dict(time=np.arange(i*12,i*12+12),lon=da_pet_template.coords['lon'],lat=da_pet_template.coords['lat']),dims=["time","lat","lon"])
    ncfile1.close()
    new_reference[i*12:(i*12+12)] = enkel_2005[:]
    
#da_pr_template.sel(time=slice('2005-01-01', '2006-01-01')) #<-- dit werkt, levert 12 data op
new_reference[12:24]
new_reference.name = 'pet'

pet_ref = new_reference

#om op te slaan (un-hashtaggen)
#new_reference.to_netcdf('/usr/people/slomp/Documents/Stage/prec_ref/ref_pet_2005_n160.nc')
# Out:
# 0

# %%
def retrieve_coef(timescale,da_ref=pr_ref,da_pet_ref=(1/86400)*pet_ref,to_save=False):
    #make a 1D timeseries, using weighted_avg function 
    da_ref_ts = pr_ref
        

    #make weighted avg of da_pet_ref
    da_pet_ts = (1/86400)*pet_ref
    
    #substract precipitation with pet
    da_pr_minus_pet = np.array(da_ref_ts) - np.array(da_pet_ts) # <-- make sure da_ref and da_pet_ref have similar units!! in numpy array as else dimension depracation
    
    #into an R-array
    r_ref_ts = r_time_series(robjects.FloatVector(da_pr_minus_pet), start = robjects.IntVector([2000, 1]), frequency = 12)
    
    #calculate SPEI and its coefficients:
    r_spei = r_spei_function(r_ref_ts, scale=timescale, na_rm=True, distribution='log-Logistic',verbose=False)
    
    #retrieve coefficients
    r_coef = r_spei.rx2('coefficients')


    #potentially save
    #---
    
    # return coefficients
    return r_coef

# %%
coef_spei = retrieve_coef(1)

# %%
coef_spei
# Out:
# <rpy2.robjects.vectors.FloatArray object at 0x150c598af080> [RTYPES.REALSXP]
# R classes: ('array',)
# [3.227678, 0.460782, -0.026468, 2.697844, ..., -0.153494, 3.073116, 0.499525, -0.217196]

# %%
r_ref_ts = r_time_series(robjects.FloatVector(wb), start = robjects.IntVector([2000, 1]), frequency = 12)

# %%
r_ref_ts
# Out:
# <rpy2.robjects.vectors.FloatVector object at 0x150c59735280> [RTYPES.REALSXP]
# R classes: ('ts',)
# [2.819387, 1.935281, 0.343196, 1.296706, ..., -1.271149, 1.049452, 1.025914, 2.283893]

# %%
r_spei = r_spei_function(r_ref_ts, scale=1, na_rm=True, distribution='log-Logistic',verbose=False)

# %%
r_spei
# Out:
# <rpy2.robjects.vectors.ListVector object at 0x150c598c7bc0> [RTYPES.VECSXP]
# R classes: ('spei',)
# [LangSexpV..., StrSexpVe..., FloatSexp..., FloatSexp..., ..., ListSexpV..., StrSexpVe..., StrSexpVe..., BoolSexpV...]
#   call: <class 'rpy2.rinterface.LangSexpVector'>
#   <rpy2.rinterface.LangSexpVector object at 0x150c59750b40> [RTYPES.LANGSXP]
#   info: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#   <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x150c59735e40> [RTYPES.STRSXP]
#   fitted: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x150c59735d00> [RTYPES.REALSXP]
#   coefficients: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x150c59735e40> [RTYPES.REALSXP]
#   scale: <class 'rpy2.rinterface.IntSexpVector'>
#   <rpy2.rinterface.IntSexpVector object at 0x150c59750fc0> [RTYPES.INTSXP]
#   kernel: <class 'rpy2.rinterface.ListSexpVector'>
# ...

# %%
coef_spei = r_spei.rx2('coefficients')

# %%
coef_spei
# Out:
# <rpy2.robjects.vectors.FloatArray object at 0x150c598af080> [RTYPES.REALSXP]
# R classes: ('array',)
# [3.227678, 0.460782, -0.026468, 2.697844, ..., -0.153494, 3.073116, 0.499525, -0.217196]

# %%
def calc_spei(da_pr,basin,timescale,coef,da_pet,to_save=False):
    #make weighted avg of both da_pr and da_pet
    da_pr_ts = weighted_avg(masks[basin],da_pr)
    da_pet_ts = weighted_avg(masks[basin],da_pet)
    
    #substract da_pet from da_pr
    da_pr_minus_pet = np.array(da_pr_ts) - np.array(da_pet_ts) # <-- in numpy array since else dimension depracation
    
    #into an R-array
    r_pr_pet_ts = r_time_series(robjects.FloatVector(da_pr_minus_pet), start = robjects.IntVector([da_pr.time.dt.year[0].values, da_pr.time.dt.month[0].values]), frequency = 12)
    
    #calculate SPEI
    r_spei = r_spei_function(r_pr_pet_ts, scale=timescale, na_rm=True, distribution='log-Logistic', params=coef,verbose=False)

    #transform to Panda Dataframe and then to xarray
    r_spei_values = pandas2ri.ri2py_vector(r_spei.rx2('fitted'))
    da_spei = xr.DataArray(r_spei_values[:],dims=da_pet_ts.dims,coords=da_pet_ts.coords) #<-- use dims/coords of timeseries of da_pr_pet
    da_spei = da_spei.astype('float32')
    
    #potentially save
    #---
    
    #return SPI values
    return da_spei

# %%
r_wb_ts = r_time_series(robjects.FloatVector(wb), start = robjects.IntVector([ds.time.dt.year[0].values, ds.time.dt.month[0].values]), frequency = 12)

# %%
r_spei = r_spei_function(r_wb_ts, scale=1, na_rm=True, distribution='log-Logistic',verbose=True)
# Out:
# [1] "Calculating the Standardized Precipitation Evapotranspiration Index (SPEI) at a time scale of 1. Using kernel type 'rectangular', with 0 shift. Fitting the data to a log-Logistic distribution. Using the ub-pwm parameter fitting method. Missing values (`NA`) will not be considered in the calculation. Using the whole time series as reference period. Input type is tsvector. Time series spanning Jan 2000 to Dec 2009, with frequency = 12."

# %%
r_spei_values = pandas2ri.ri2py_vector(r_spei.rx2('fitted'))

# %%
#plt.plot(dayTSwb[3500::])
#plt.plot(dayTSpr[3500::]*60*60*24)
plt.plot(dayTSpet[3500::])

# %%
# plt.plot(r_spei_values_day[3500::])
# plt.plot(r_spei_values_day2[3500::])

plt.plot(r_spei_values_day[3200:3300])
plt.plot(r_spei_values_day2[3200:3300])

#plt.plot(dayTSwb[0:365])
# plt.plot(dayTSpet[0:365])
# plt.plot(dayTSpr[0:365]*60*60*24)

# %%
plt.plot(r_spei_values_day2[3500::] - r_spei_values_day[3500::])
#plt.plot(r_spei_values_day[1300:1400] - r_spei_values_day2[1300:1400])

# %%
plt.plot(np.diff(r_spei_values_day)[3200:3300:4])

# %%
plt.plot(np.diff(np.diff(r_spei_values_day))[3500::])

# %%
r_spei_values_day
# Out:
# array([        nan,         nan,         nan, ..., -1.41970612,
#        -1.10516949, -0.95782406])

# %%
pd.Series(r_spei_values_day).rolling(window=4).mean().iloc[4-1:].values
# Out:
# array([        nan,         nan,         nan, ..., -1.60814781,
#        -1.42915365, -1.24096881])

# %%
plt.plot(r_spei_values_day)
plt.plot(pd.Series(r_spei_values_day).rolling(window=4).mean().iloc[4-1:].values)

# %%
plt.plot(dayTSpet[3520:3560], label='pet')
plt.plot(dayTSpr[3520:3560]*60*60*24, label='precip')
plt.plot(dayTSwb[3520:3560], label='wb')
plt.legend()

# %%
# np.diff(r_spei_values_day)
plt.plot(r_spei_values_day[3520:3560], label='SPEI1')


for i in np.arange(1,10,1):
    N=i
    plt.plot(pd.Series(np.diff(r_spei_values_day[3520-N:3560-N])).rolling(window=N).sum().iloc[N-1:].values, label=f'd-{N}')
    

plt.legend()
plt.title('SPEI1 & 1st order time deriv. dSPEI1 rol.sum window d-N')
# Out:
# Text(0.5, 1.0, 'SPEI1 & 1st order time deriv. dSPEI1 rol.sum window d-N')

# %%
# np.diff(r_spei_values_day)
plt.plot(r_spei_values_day[3520:3560], label='SPEI1')


for i in np.arange(1,10,1):
    N=i
    plt.plot(pd.Series(np.diff(np.diff(r_spei_values_day[3520-N:3560-N]))).rolling(window=N).sum().iloc[N-1:].values, label=f'dd-{N}')
    

plt.legend()
plt.title('SPEI1 & 2nd order time deriv. ddSPEI1 rol.sum window dd-N')
# Out:
# Text(0.5, 1.0, 'SPEI1 & 2nd order time deriv. ddSPEI1 rol.sum window dd-N')

# %%
N=8
plt.plot(pd.Series(np.diff(np.diff(r_spei_values_day[3520-N:3560-N]))).rolling(window=N).sum().iloc[N-1:].values, label=f'dd-{N}')

# %%
N=30

xday = np.arange(0,np.shape(r_spei_values_day)[0]-N+1,1)
xmon = np.arange(0,np.shape(r_spei_values_day)[0],np.shape(r_spei_values_day)[0]/np.shape(r_spei_values)[0])

plt.plot(xday,pd.Series(r_spei_values_day).rolling(window=N).mean().iloc[N-1:].values, label=f'{N}day mean SPEI1')
plt.plot(xmon,r_spei_values, label=f'monthly SPEI1')
plt.legend()
plt.title('h010: SPEI1 monthly and daily 30day mean ')
# Out:
# Text(0.5, 1.0, 'h010: SPEI1 monthly and daily 30day mean ')

# %%
N=30

xday = np.arange(0,np.shape(r_spei_values_day[0:365])[0]-N+1,1)
xmon = np.arange(0,np.shape(r_spei_values_day[0:365])[0],np.shape(r_spei_values_day[0:365])[0]/np.shape(r_spei_values[0:11])[0])

plt.plot(xday,pd.Series(r_spei_values_day[0:365]).rolling(window=N).mean().iloc[N-1:].values, label=f'{N}day mean SPEI1')
plt.plot(xmon,r_spei_values[0:11], label=f'monthly SPEI1')
plt.legend()
plt.title('h010: SPEI1 monthly and daily 30day mean ')
# Out:
# Text(0.5, 1.0, 'h010: SPEI1 monthly and daily 30day mean ')

# %%
xday = np.arange(0,np.shape(r_spei_values_day)[0],1)

# %%
xday

# %%
np.shape(xday)[0]
# Out:
# 3650

# %% [markdown]
# ## now do daily

# %%
var='pr'
freq='day'
timeslice='PD'
i='01'
j='0'
diri='/perm/nklm/Px_drought/testing/LENTIS/'

ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)

# %%
dayTSpr, box_seasons = calc_boxstat(ds, 'pr', area='rhine')

# %%
var='pet'
freq='day'
timeslice='PD'
i='01'
j='0'
diri='/perm/nklm/Px_drought/testing/LENTIS/'

ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)

# %%
dayTSpet, box_seasons = calc_boxstat(ds, 'pet_pm_asce', area='rhine')

# %%
dayTSpet['time'] = dayTSpr.time

# %%
dayTSwb=((dayTSpr*60*60*24) - dayTSpet)

# %%
ref_dayTSwb = dayTSwb.sel(time=slice('2005-01-01', '2005-12-26'))

# %%
np.shape(ref_dayTSwb)
# Out:
# (360,)

# %%
r_ref_ts = r_time_series(robjects.FloatVector(ref_dayTSwb), start = robjects.IntVector([2005, 1]), frequency = 360)

# %%
r_ref_ts
# Out:
# <rpy2.robjects.vectors.FloatVector object at 0x14c419aea680> [RTYPES.REALSXP]
# R classes: ('ts',)
# [4.171543, 9.007282, 9.762441, 6.328103, ..., 1.818712, 2.376393, 2.826340, 0.766838]

# %%
#r_coef_day = 
r_spei_day = r_spei_function(r_ref_ts, scale=30, na_rm=True, distribution='log-Logistic',verbose=False) #.rx2('coefficients')

# %%
r_spei_day = r_spei_function(r_ref_ts, scale=30, na_rm=True, distribution='log-Logistic',verbose=False)

# %%
r_coef_day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 r_coef_day
#
# NameError: name 'r_coef_day' is not defined

# %%
r_spei_day
# Out:
# <rpy2.robjects.vectors.ListVector object at 0x14c40a09e300> [RTYPES.VECSXP]
# R classes: ('spei',)
# [LangSexpV..., StrSexpVe..., FloatSexp..., BoolSexpV..., ..., ListSexpV..., StrSexpVe..., StrSexpVe..., BoolSexpV...]
#   call: <class 'rpy2.rinterface.LangSexpVector'>
#   <rpy2.rinterface.LangSexpVector object at 0x14c409ee8700> [RTYPES.LANGSXP]
#   info: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#   <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x14c409f58f80> [RTYPES.STRSXP]
#   fitted: <class 'rpy2.rinterface.FloatSexpVector'>
#   <rpy2.rinterface.FloatSexpVector object at 0x14c409fcaac0> [RTYPES.REALSXP]
#   coefficients: <class 'rpy2.rinterface.BoolSexpVector'>
#   <rpy2.rinterface.BoolSexpVector object at 0x14c40a0276c0> [RTYPES.LGLSXP]
#   scale: <class 'rpy2.rinterface.IntSexpVector'>
#   <rpy2.rinterface.IntSexpVector object at 0x14c40a142380> [RTYPES.INTSXP]
#   kernel: <class 'rpy2.rinterface.ListSexpVector'>
# ...

# %% [markdown]
# ###

# %%
# nu met de hele 10 jaar probere 

r_wb = r_time_series(robjects.FloatVector(dayTSwb[:-3]), start = robjects.IntVector([2000, 1]), frequency = 365)
r_spei_day = r_spei_function(r_wb, scale=30, na_rm=True, distribution='log-Logistic',verbose=False) #.rx2('coefficients')

# %%
r_spei_values_day = pandas2ri.ri2py_vector(r_spei_day.rx2('fitted'))

# %%
3650/120
# Out:
# 30.416666666666668

# %%
start_day=2
end_day=27+start_day
ref_dayTSwb = dayTSwb.sel(time=slice(f'2000-01-{start_day}', f'2009-12-{end_day}'))

# %%
ref_dayTSwb
# Out:
# <xarray.DataArray (time: 3650)>
# array([13.56107732,  4.29262664,  2.23059157, ..., 12.28249115,
#         0.22524252, -0.21315824])
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-02T12:00:00 ... 2009-12-29T12:00:00

# %%
r_ref_ts = r_time_series(robjects.FloatVector(ref_dayTSwb), start = robjects.IntVector([2000, start_day]), frequency = np.shape(ref_dayTSwb)[0]/10.)

# %%
r_spei_day2 = r_spei_function(r_ref_ts, scale=30, na_rm=True, distribution='log-Logistic',verbose=False)

# %%
r_spei_values_day2 = pandas2ri.ri2py_vector(r_spei_day2.rx2('fitted'))

# %%
fig,ax = plt.subplots(1, 1,figsize=(14,4))

plt.axhline(y=-1, color='r', linestyle='-')
plt.axhline(y=0, color='k', linestyle='-', linewidth=0.5)
plt.plot(r_spei_values_day2, label='SPEI1')

# idx = np.argwhere(np.isclose(r_spei_values, -1, atol=0.1)).reshape(-1)

# for i in range(0,np.shape(idx)[0]):
#     plt.axvline(x=idx[i]) #x3[idx], y2_new[idx], 'ro')

xaxis = range(0,np.shape(r_spei_values_day2)[0])
plt.fill_between(xaxis,-1,r_spei_values_day2,where =  (r_spei_values_day2 <= -1), color='r',alpha=0.3,linewidth=0,zorder=5)


plt.legend()
plt.title('SPEI1 in the Rhine basin based on daily values')
# Out:
# Text(0.5, 1.0, 'SPEI1 in the Rhine basin based on daily values')

# %%
r_spei_values_day2
# Out:
# array([        nan,         nan,         nan, ..., -1.10516949,
#        -0.95782406, -0.93171941])

# %%
def calc_spei_daily(ds_wb, start_day):
    end_day=25+start_day
    ref_dayTSwb = ds_wb.sel(time=slice(f'2000-01-{start_day}', f'2009-12-{end_day}'))
    np.shape(ref_dayTSwb)
    r_ref_ts = r_time_series(robjects.FloatVector(ref_dayTSwb), start = robjects.IntVector([2000, start_day]), frequency = np.shape(ref_dayTSwb)[0]/10)
    r_spei_day = r_spei_function(r_ref_ts, scale=30, na_rm=True, distribution='log-Logistic',verbose=False)
    r_spei_values_day = pandas2ri.ri2py_vector(r_spei_day.rx2('fitted'))
    
    return r_spei_values_day

# %%
r_spei_values_day2= calc_spei_daily(dayTSwb, 2)

# %%
r_spei_values_day2
# Out:
# array([        nan,         nan,         nan, ..., -1.10516949,
#        -0.95782406, -0.93171941])

# %%
r_spei_values_day
# Out:
# array([        nan,         nan,         nan, ..., -1.41970612,
#        -1.10516949, -0.95782406])

# %% [markdown]
# #### Have a bunch of necessary definitions

# %%
def open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None):
    """
    Open one LENTIS data file from the ensemle
    """
    if timeslice == 'PD': 
        letter = 'h'
    elif timeslice == '2K': 
        letter = 's'
        
    ens_member=f'{letter}{str(i).zfill(2)}{str(j)}'
    
    file=f"{diri}/{timeslice}/{freq}/{var}/{var}_{ens_member}.nc"
    
    if plev != None:
        ds=xr.open_dataset(file).sel(plev=plev)
    else:
        ds=xr.open_dataset(file)
    
    return ds, ens_member

# %%
def calc_boxstat(ds, var, area='global'): 
    """
    Compute spatial weighted mean
    ds      :  xarray DataArray
    """ 
    box_seasons = ds.time.dt.season

    if hasattr(ds, 'lat'):
            weights = np.cos(ds.lat * np.pi / 180)
    elif hasattr(ds, 'latitude'):
            weights = np.cos(ds.latitude * np.pi / 180)

    if area=='global':
        if hasattr(ds, 'lat'):
            boxstat = ds[var].weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].weighted(weights).mean(dim=('latitude','longitude')) 
    elif area=='nh':
        if hasattr(ds, 'lat'): 
            boxstat = ds[var].sel(lat=slice(0,90)).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].sel(latitude=slice(0,90)).weighted(weights).mean(dim=('latitude','longitude')) 
    elif area=='europe':
        if hasattr(ds, 'lat'):
            boxstat = ds[var].sel(lat=slice(30,70),lon=slice(-10,40)).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].sel(latitude=slice(30,70),longitude=slice(-10,40)).weighted(weights).mean(dim=('latitude','longitude'))  

    # regions for Pieter Slomp
    elif area in ['rhine',]:
        path_mask = '/perm/nklm/Px_drought/' + area + '.nc'
        basin_mask = xr.open_dataset(path_mask).catchmentID[0,:,:]

        if hasattr(ds, 'lat'):
            boxstat = ds[var].where(basin_mask).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].where(basin_mask).weighted(weights).mean(dim=('latitude','longitude'))   
            
    # regions for Leonie Hemelrijk
    elif area=='LH_westEU':
        if hasattr(ds, 'lat'):
            boxstat = ds[var].sel(lat=slice(30,60),lon=slice(-30,30)).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].sel(latitude=slice(30,60),longitude=slice(-30,30)).weighted(weights).mean(dim=('latitude','longitude'))    
    elif area=='LH_rhine':
        if hasattr(ds, 'lat'):
            boxstat = ds[var].sel(lat=slice(47,55),lon=slice(2,10)).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].sel(latitude=slice(47,55),longitude=slice(2,10)).weighted(weights).mean(dim=('latitude','longitude'))

    else:
        raise ValueError('unknown area: '+area)
            
            
    return boxstat, box_seasons

# %%
def get_attr_info(var, freq, timeslice, diri):
    """
    
    """
    ds, ens_member = open_one_LENTIS(var, freq, timeslice, 1, 1, diri)
    
    # get global attributes
    attrs=ds.attrs
    
    # get coordinates
    time_attrs=ds.time.attrs
    lat_attrs=ds.lat.attrs
    lon_attrs=ds.lon.attrs

    # get coordinate bounds 
    time_bnds=ds.time_bnds
    lat_bnds=ds.lat_bnds
    lon_bnds=ds.lon_bnds
    
    # get part of the var attributes
    var_units=ds[var].units
    var_standard_name=ds[var].standard_name
    var_long_name=ds[var].long_name
    
    
    return attrs, time_attrs, time_bnds, var_units, var_standard_name, var_long_name

# %%
def calc_ens_statistics_and_to_netcdf(var, freq, timeslice, plev, diri, diro, area='global', seas='ANN', statistic='mean'):
    '''
    """Compute the annual-averaged, global weighted mean 
    for a given variable, for all ensemble members of a time slice"""
    '''
    
    # define variables of the computed quantity and its ensemble member
    ens_stat_values=[]
    ens_member_list=[]
    
    # Do the calculation
    for i in np.arange(1,16+1):
        for j in np.arange(0,9+1):
            ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev)
            #ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri)
            boxstat,box_seasons = calc_boxstat(ds, var, area)
            seasonal_avg = calc_seasonal_avg(boxstat,box_seasons, seas)

            ens_stat_values.append(seasonal_avg)
            ens_member_list.append(ens_member)
            del ds,boxstat,seasonal_avg,ens_member

    
    # Prepare xarray.dataset to save as Netcdf file
    attrs, time_attrs, time_bnds, var_units, var_standard_name, var_long_name = get_attr_info(var,freq,timeslice, diri)
    
    # time_attrs = {'standard_name': 'time',
    #                 'long_name': 'time',
    #                 'bounds': 'time_bnds',
    #                 'axis': 'T'}
    
    time_bnds_combined, time_avg = get_avg_timebnds(var, freq, timeslice, diri, seas)
    
    ens_attrs = {'standard_name': 'ens_mem',
                 'long_name': 'Ensemble member',
                 'comment': 'Postprocessed by Laura Muntjewerf (KNMI). A time slice of KNMI-LENTIS consists of 16 ensemble member of 10 years. All simulations have a unique ensemble member label that reflects the forcing, and how the initial conditions are generated. The initial conditions have two aspects: the parent simulation from which the run is branched (macro perturbation, there are 16), and the seed relating to a particular micro-perturbation in the initial three-dimensional atmosphere temperature field (there are 10). The ensemble member label thus is a combination of: forcing (h for present-dsy/historical and s for +2K/SSP2-4.5), parent ID (number between 1 and 16), micro perturbation ID (number between 0 and 9) '}
    coords={'time': (['time'], time_avg.data, time_attrs),
            'ens': (['ens'], ens_member_list, ens_attrs)
            }
    
    var_attr = {'units': var_units, 
                        'standard_name': f'{var_standard_name}_{area}_{seas}_{statistic}',
                        'long_name': f'{statistic} {var_long_name} of {area} ({seas})'}
                    
    
    # define data with variable attributes as Xarray dataset
    ds_new = xr.Dataset(
    data_vars=dict(
        time_bnds=(["time", "bnds"], 
                     time_bnds_combined,{}),
        ens_bnds=(["ens"], 
                     ens_member_list,{}),
        var=(['ens','time'],  
                      ens_stat_values, 
                       var_attr,
    )),
    coords=coords,
    attrs=attrs,
    )
    
    # assign encoding
    # otherwise it will throw error when opening with nvciew --> (ncview: netcdf_dim_value: unknown data type (10) for dimension time) en (unknown data type (12) for dimension ens)
    ds_new.ens.encoding = {'zlib': False,
                     'shuffle': False,
                     'complevel': 0,
                     'fletcher32': False,
                     'contiguous': False,
                     'chunksizes': None,
                     'dtype': '|S1'}

    ds_new.time.encoding = {'zlib': False,
                        'shuffle': False,
                        'complevel': 0,
                        'fletcher32': False,
                        'contiguous': False,
                        'dtype': np.dtype('float64'),
                        'units': 'days since 1850-01-01 00:00:00',
                        'calendar': 'proleptic_gregorian'
                        }

    

    # create dataset
    # Save in right location
    
    if plev != None:
        filo=f'{timeslice}_ensemble_{area}_{seas}_{freq}_{var}_{plev}_mean.nc'
    else:
        filo=f'{timeslice}_ensemble_{area}_{seas}_{freq}_{var}_mean.nc'
    

    ds_new.to_netcdf(f'{diro}/{filo}', unlimited_dims='ens')
