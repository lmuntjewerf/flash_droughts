# %%
import xarray as xr
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
vars=['pet']
freq='day'
timeslices=['PD',]
i='01'
j='0'
area='rhine'
diri='/perm/nklm/Px_drought/testing/LENTIS/'
quantiles = [0.1, 0.25, 0.5, 0.75, 0.9]

for var in vars:
    for timeslice in timeslices:
        if timeslice == 'PD':
            colour = 'royalblue'
        elif timeslice == '2K':
            colour = 'firebrick'


        # colour = 'royalblue'
        ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)
        boxstat, box_seasons = calc_boxstat(ds, var, area)
        annual_cycle_spread = calc_annual_cycle_quantiles(boxstat, quantiles)

        fig,ax = plt.subplots(1, 1,figsize=(7,4))
        plot_annual_cycle_quantiles(fig, annual_cycle_spread, quantiles, colour)
        ax.set_xlabel('days')
        
        if var == 'pet':
            var = 'pet_pm_asce'
        
        ax.set_ylabel(ds[var].units)
        ax.set_title(ds[var].long_name)
        
        plt.savefig(f'plots/ann_cycle_rhine_{var}_{timeslice}.png')

        plt.show()
# Out:
# 3
# 0.1
# 0.25
# 0.5
# 0.75
# 0.9

# %%
vars=['pet']
freq='day'
timeslices=['2K',]
i='01'
j='0'
area='rhine'
diri='/perm/nklm/Px_drought/testing/LENTIS/'
quantiles = [0.1, 0.25, 0.5, 0.75, 0.9]

for var in vars:
    for timeslice in timeslices:
        if timeslice == 'PD':
            colour = 'royalblue'
        elif timeslice == '2K':
            colour = 'firebrick'


        # colour = 'royalblue'
        ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)
        boxstat, box_seasons = calc_boxstat(ds, var, area)
        annual_cycle_spread = calc_annual_cycle_quantiles(boxstat, quantiles)

        fig,ax = plt.subplots(1, 1,figsize=(7,4))
        plot_annual_cycle_quantiles(fig, annual_cycle_spread, quantiles, colour)
        ax.set_xlabel('days')
        
        if var == 'pet':
            var = 'pet_pm_asce'
        
        ax.set_ylabel(ds[var].units)
        ax.set_title(ds[var].long_name)
        
        plt.savefig(f'plots/ann_cycle_rhine_{var}_{timeslice}.png')

        plt.show()
# Out:
# 3
# 0.1
# 0.25
# 0.5
# 0.75
# 0.9

# %%
# vars=['mrso','mrsos','pr']
freq='day'
timeslices=['PD','2K']
i='01'
j='0'
area='rhine'
diri='/perm/nklm/Px_drought/testing/LENTIS/'
quantiles = [0.1, 0.25, 0.5, 0.75, 0.9]

for var in 'pr',:
    for timeslice in timeslices:
        if timeslice == 'PD':
            colour = 'royalblue'
        elif timeslice == '2K':
            colour = 'firebrick'

        ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)
        boxstat, box_seasons = calc_boxstat(ds, var, area)
        if var == 'pr':
            boxstat = boxstat*60*60*24
        annual_cycle_spread = calc_annual_cycle_quantiles(boxstat, quantiles)

        fig,ax = plt.subplots(1, 1,figsize=(7,4))
        plot_annual_cycle_quantiles(fig, annual_cycle_spread, quantiles, colour)
        ax.set_xlabel('days')
        
        if var == 'pr':
            ax.set_ylabel('mm/day')
        else:
            ax.set_ylabel(ds[var].units)
        ax.set_title(ds[var].long_name)
        
        plt.savefig(f'plots/ann_cycle_rhine_{var}_{timeslice}.png')
        plt.show()

        # c
# Out:
# 3
# 0.1
# 0.25
# 0.5
# 0.75
# 0.9
# 3
# 0.1
# 0.25
# 0.5
# 0.75
# 0.9

# %%
var='mrsos'
freq='day'
timeslice='PD'
i='01'
j='0'
area='rhine'
diri='/perm/nklm/Px_drought/testing/LENTIS/'
quantiles = [0.1, 0.25, 0.5, 0.75, 0.9]


colour = 'royalblue'
ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)
boxstat, box_seasons = calc_boxstat(ds, var, area)
annual_cycle_spread = calc_annual_cycle_quantiles(boxstat, quantiles)

fig,ax = plt.subplots(1, 1,figsize=(7,4))
plot_annual_cycle_quantiles(fig, annual_cycle_spread, quantiles, colour)
ax.set_xlabel('days')
ax.set_ylabel(ds[var].units)
ax.set_title(ds[var].long_name)
plt.show()

# calc_and_plot_ann_cycle(var, freq, timeslice, i, j, diri,area, quantiles, colour)
# Out:
# 3
# 0.1
# 0.25
# 0.5
# 0.75
# 0.9
# <AxesSubplot: >

# %%
vars=['mrso','mrsos','pr','pet']
freq='day'
timeslices=['PD','2K']
i='01'
j='0'
area='rhine'
diri='/perm/nklm/Px_drought/testing/LENTIS/'
quantiles = [0.1, 0.25, 0.5, 0.75, 0.9]

for var in vars:
    for timeslice in timeslices:
        if timeslice == 'PD':
            colour = 'royalblue'
        elif timeslice == '2K':
            colour = 'firebrick'
            
        calc_and_plot_ann_cycle(var, freq, timeslice, i, j, diri,area, quantiles, colour)
# Out:
# /perm/nklm/mambaforge/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /perm/nklm/mambaforge/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /perm/nklm/mambaforge/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /perm/nklm/mambaforge/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /perm/nklm/mambaforge/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# ...

# %%
np.shape(iets[1])[0]
# Out:
# 2

# %%
tests = [1,66,3,77,4,16.,7,98,83,6,5,24,3,15]

# %%
testspr = []
for quantile in [0.1, 0.25, 0.5, 0.75, 0.9]:
    tests*quantile
    #testspr.append([quantile, tests*quantile])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 testspr = []
#       2 for quantile in [0.1, 0.25, 0.5, 0.75, 0.9]:
# ----> 3     tests*quantile
#       4     #testspr.append([quantile, tests*quantile])
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
var='mrsos'
freq='day'
timeslice='PD'
i='01'
j='0'
area='rhine'
diri='/perm/nklm/Px_drought/testing/LENTIS/'

ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)

# %%
ts_mrsos_day, box_seasons = calc_boxstat(ds, var, area=area)

# %%
quantiles = [0.1, 0.25, 0.5, 0.75, 0.9]
annual_cycle_spread = calc_annual_cycle_quantiles(ts_mrsos_day,quantiles)

# %%
# Out:
# 3
# 0.1
# 0.25
# 0.5
# 0.75
# 0.9
# <AxesSubplot: >

# %%
print(str(f'P{int(annual_cycle_spread[quantile-1][0]*100)}'))
# Out:
# P90

# %%
fig,ax = plt.subplots(1, 1,figsize=(7,4))

colour1='b'

middle_quantile = int(np.ceil(np.shape(quantiles)[0]/2))

number_quantile_pairs = middle_quantile
    
for quantile in range(1,np.shape(quantiles)[0]+1):
    alpha_line = 0.8 - (1/middle_quantile)*abs(middle_quantile - quantile)
    print(annual_cycle_spread[quantile-1][0])
    ax.plot(annual_cycle_spread[quantile-1][1],color=colour1,alpha=alpha_line)
    quantile_string = str(f'P{int(annual_cycle_spread[quantile-1][0]*100)}')
    ax.text(-18,annual_cycle_spread[quantile-1][1][0],quantile_string,fontsize=10,color=colour1,alpha=alpha_line)
    
    if not quantile == middle_quantile and quantile <= middle_quantile:
        # alpha_fill = 1 - (1/middle_quantile)*abs(middle_quantile - quantile)
        # print(alpha_fill)
        xaxis = range(0,np.shape(annual_cycle_spread[0][1])[0]-1)
        ax.fill_between(xaxis,annual_cycle_spread[quantile-1][1][0:365],annual_cycle_spread[quantile][1][0:365],color=colour1,alpha=alpha_line,linewidth=0,zorder=5)
        
    elif not quantile == middle_quantile and quantile >= middle_quantile:
        xaxis = range(0,np.shape(annual_cycle_spread[0][1])[0]-1)
        ax.fill_between(xaxis,annual_cycle_spread[quantile-2][1][0:365],annual_cycle_spread[quantile-1][1][0:365],color=colour1,alpha=alpha_line,linewidth=0,zorder=5)
# Out:
# 0.1
# 0.25
# 0.5
# 0.75
# 0.9

# %%
ds[var].long_name
# Out:
# 'Total Soil Moisture Content'

# %%
plt.fill_between(xaxis,annual_cycle_spread[quantile-1][1][0:365],annual_cycle_spread[quantile][1][0:365],color=colour1,alpha=alpha_fill,linewidth=0,zorder=5)

# %%
fig,ax = plt.subplots(1, 1,figsize=(7,4))
ax = plot_annual_cycle_quantiles(fig, annual_cycle_spread,quantiles, 'k')
ax.set_xlabel('days')
ax.set_ylabel(ds[var].units)
ax.set_title(ds[var].long_name)
plt.show()
# Out:
# 0.1
# 0.25
# 0.5
# 0.75
# 0.9

# %%
def calc_and_plot_ann_cycle(var, freq, timeslice, i, j, diri,area, quantiles, colour):
    ds, ens_member = open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None)
    boxstat, box_seasons = calc_boxstat(ds, var, area)
    annual_cycle_spread = calc_annual_cycle_quantiles(boxstat, quantiles)
    
    fig,ax = plt.subplots(1, 1,figsize=(7,4))
    ax = plot_annual_cycle_quantiles(fig, annual_cycle_spread,quantiles, colour)
    ax.set_xlabel('days')
    ax.set_ylabel(ds[var].units)
    ax.set_title(ds[var].long_name)
    plt.show()

# %%
def plot_annual_cycle_quantiles(fig, annual_cycle_spread,quantiles, colour):
    
    middle_quantile = int(np.ceil(np.shape(quantiles)[0]/2))
    print(middle_quantile)
    
    number_quantile_pairs = middle_quantile
        
    for quantile in range(1,np.shape(quantiles)[0]+1):
        alpha_line = 0.8 - (1/middle_quantile)*abs(middle_quantile - quantile)
        print(annual_cycle_spread[quantile-1][0])
        ax.plot(annual_cycle_spread[quantile-1][1],color=colour,alpha=alpha_line)
        quantile_string = str(f'P{int(annual_cycle_spread[quantile-1][0]*100)}')
        ax.text(-18,annual_cycle_spread[quantile-1][1][0],quantile_string,fontsize=10,color=colour,alpha=alpha_line)
        
        if not quantile == middle_quantile and quantile <= middle_quantile:
            # alpha_fill = 1 - (1/middle_quantile)*abs(middle_quantile - quantile)
            # print(alpha_fill)
            xaxis = range(0,np.shape(annual_cycle_spread[0][1])[0]-1)
            ax.fill_between(xaxis,annual_cycle_spread[quantile-1][1][0:365],annual_cycle_spread[quantile][1][0:365],color=colour,alpha=alpha_line,linewidth=0,zorder=5)
            
        elif not quantile == middle_quantile and quantile >= middle_quantile:
            xaxis = range(0,np.shape(annual_cycle_spread[0][1])[0]-1)
            ax.fill_between(xaxis,annual_cycle_spread[quantile-2][1][0:365],annual_cycle_spread[quantile-1][1][0:365],color=colour,alpha=alpha_line,linewidth=0,zorder=5)
            
    return ax

# %%
def open_one_LENTIS(var, freq, timeslice, i, j, diri, plev=None):
    """
    Open one LENTIS data file from the ensemle
    """
    if timeslice == 'PD': 
        letter = 'h'
    elif timeslice == '2K': 
        letter = 's'
        
    ens_member=f'{letter}{str(i).zfill(2)}{str(j)}'
    
    file=f"{diri}/{timeslice}/{freq}/{var}/{var}_{ens_member}.nc"
    
    if plev != None:
        ds=xr.open_dataset(file).sel(plev=plev)
    else:
        ds=xr.open_dataset(file)
    
    return ds, ens_member

# %%
def calc_annual_cycle_quantiles(ds, quantiles):
    annual_cycle_spread = []
    
    for quantile in quantiles:
        annual_cycle_quantile = ds.groupby('time.dayofyear').quantile(quantile, dim='time',method='nearest')
        annual_cycle_spread.append([quantile, annual_cycle_quantile])
        
    return annual_cycle_spread

# %%
def calc_boxstat(ds, var, area='global'): 
    """
    Compute spatial weighted mean
    ds      :  xarray DataArray
    """ 
    
    if var == 'pet':
        var = 'pet_pm_asce'
        
        
    box_seasons = ds.time.dt.season

    if hasattr(ds, 'lat'):
            weights = np.cos(ds.lat * np.pi / 180)
    elif hasattr(ds, 'latitude'):
            weights = np.cos(ds.latitude * np.pi / 180)

    if area=='global':
        if hasattr(ds, 'lat'):
            boxstat = ds[var].weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].weighted(weights).mean(dim=('latitude','longitude')) 
    elif area=='nh':
        if hasattr(ds, 'lat'): 
            boxstat = ds[var].sel(lat=slice(0,90)).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].sel(latitude=slice(0,90)).weighted(weights).mean(dim=('latitude','longitude')) 
    elif area=='europe':
        if hasattr(ds, 'lat'):
            boxstat = ds[var].sel(lat=slice(30,70),lon=slice(-10,40)).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].sel(latitude=slice(30,70),longitude=slice(-10,40)).weighted(weights).mean(dim=('latitude','longitude'))  

    # regions for Pieter Slomp
    elif area in ['rhine',]:
        path_mask = '/perm/nklm/Px_drought/' + area + '.nc'
        basin_mask = xr.open_dataset(path_mask).catchmentID[0,:,:]

        if hasattr(ds, 'lat'):
            boxstat = ds[var].where(basin_mask).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].where(basin_mask).weighted(weights).mean(dim=('latitude','longitude'))   
            
    # regions for Leonie Hemelrijk
    elif area=='LH_westEU':
        if hasattr(ds, 'lat'):
            boxstat = ds[var].sel(lat=slice(30,60),lon=slice(-30,30)).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].sel(latitude=slice(30,60),longitude=slice(-30,30)).weighted(weights).mean(dim=('latitude','longitude'))    
    elif area=='LH_rhine':
        if hasattr(ds, 'lat'):
            boxstat = ds[var].sel(lat=slice(47,55),lon=slice(2,10)).weighted(weights).mean(dim=('lat','lon')) 
        elif hasattr(ds, 'latitude'):
            boxstat = ds[var].sel(latitude=slice(47,55),longitude=slice(2,10)).weighted(weights).mean(dim=('latitude','longitude'))

    else:
        raise ValueError('unknown area: '+area)
            
            
    return boxstat, box_seasons
